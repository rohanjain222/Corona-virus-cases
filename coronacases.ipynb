# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
PRS = pd.read_csv("PRSlegislativecorona_cases.csv")

# %%
Mygov = pd.read_csv("MygovIndiacorona_cases.csv")

# %%
PRS.head()
# Out:
#   PRS Legislative Research                   Unnamed: 1       Unnamed: 2  \
# 0                     S.no                       States  Confirmed cases
# 1                        1  Andaman and Nicobar Islands            10157
# 2                        2               Andhra Pradesh          2321379
# 3                        3            Arunachal Pradesh            64518
# 4                        4                        Assam           724788
#
#      Unnamed: 3       Unnamed: 4 Unnamed: 5
# 0  Active cases  Cured/Discharge      Death
# 1            42             9986        129
# 2           755          2305893      14731
# 3             4            64218        296
# 4           395           716405       7988

# %%
PRS = pd.read_csv("PRSlegislativecorona_cases.csv", header =1)

# %%
PRS.head()
# Out:
#    S.no                       States  Confirmed cases  Active cases  \
# 0     1  Andaman and Nicobar Islands            10157            42
# 1     2               Andhra Pradesh          2321379           755
# 2     3            Arunachal Pradesh            64518             4
# 3     4                        Assam           724788           395
# 4     5                        Bihar           832581           934
#
#    Cured/Discharge  Death
# 0             9986    129
# 1          2305893  14731
# 2            64218    296
# 3           716405   7988
# 4           819388  12259

# %%
Mygov = pd.read_csv("MygovIndiacorona_cases.csv", header = 1)

# %%
Mygov.head()
# Out:
#    S.no               States  Confirmed cases  Active cases  Cured/Discharge  \
# 0     1  Andaman and Nicobar            10766             0            10637
# 1     2       Andhra Pradesh          2340672             0          2325939
# 2     3    Arunachal Pradesh            67046             0            66750
# 3     4                Assam           746150             7           738108
# 4     5                Bihar           855260             1           842945
#
#    Death
# 0    129
# 1  14733
# 2    296
# 3   8035
# 4  12314

# %%
Mygov.head()
# Out:
#    S.no               States  Confirmed cases  Active cases  Cured/Discharge  \
# 0     1  Andaman and Nicobar            10766             0            10637
# 1     2       Andhra Pradesh          2340672             0          2325939
# 2     3    Arunachal Pradesh            67046             0            66750
# 3     4                Assam           746150             7           738108
# 4     5                Bihar           855260             1           842945
#
#    Death
# 0    129
# 1  14733
# 2    296
# 3   8035
# 4  12314

# %%
Mygov.drop(['S.no'],axis =1)
# Out:
#                                       States  Confirmed cases  Active cases  \
# 0                        Andaman and Nicobar            10766             0
# 1                             Andhra Pradesh          2340672             0
# 2                          Arunachal Pradesh            67046             0
# 3                                      Assam           746150             7
# 4                                      Bihar           855260             1
# 5                                 Chandigarh           100691             2
# 6                               Chhattisgarh          1187686             5
# 7   Dadra and Nagar Haveli and Daman and Diu            11592             0
# 8                                      Delhi          2040782             9
# 9                                        Goa           263311             8
# 10                                   Gujarat          1291355             8
# ...

# %%
PRS.drop(['S.no'],axis =1)
# Out:
#                                       States  Confirmed cases  Active cases  \
# 0                Andaman and Nicobar Islands            10157            42
# 1                             Andhra Pradesh          2321379           755
# 2                          Arunachal Pradesh            64518             4
# 3                                      Assam           724788           395
# 4                                      Bihar           832581           934
# 5                                 Chandigarh            93785           568
# 6                               Chhattisgarh          1154179           861
# 7   Dadra and Nagar Haveli and Daman and Diu            11474            14
# 8                                      Delhi          1934009          4325
# 9                                        Goa           248540           982
# 10                                   Gujarat          1231483          2914
# ...

# %%
NDTV.drop(['S.no'],axis =1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-56c457def913> in <module>
# ----> 1 NDTV.drop(['S.no'],axis =1)
#
# NameError: name 'NDTV' is not defined

# %%
PRS['Confirmed cases'] = PRS['Confirmed cases'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Confirmed cases')
plt.ylabel('Confirmed cases')
plt.legend(title='Statewise Confirmed Corona cases by PRS legastive')
plt.show()

# %%
PRS['Active cases'] = PRS['Active cases'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Active cases')
plt.ylabel('Active cases')
plt.legend(title='Statewise Active Corona cases by PRS legastive')
plt.show()

# %%
PRS['Cured/Discharge'] = PRS['Cured/Discharge'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Cured/Discharge')
plt.ylabel('Cured/Discharge')
plt.legend(title='Statewise Cured/Discharge by PRS legastive')
plt.show()

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Death')
plt.ylabel('Death')
plt.legend(title='Statewise Death cases by PRS legastive')
plt.show()

# %%
Mygov['Confirmed cases'] = Mygov['Confirmed cases'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Confirmed cases')
plt.ylabel('Confirmed cases')
plt.legend(title='Statewise Confirmed Corona cases by MyGov India')
plt.show()

# %%
Mygov['Active cases'] = Mygov['Active cases'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Active cases')
plt.ylabel('Active cases')
plt.legend(title='Statewise Active Corona cases by MyGov India')
plt.show()

# %%
Mygov['Cured/Discharge'] = Mygov['Cured/Discharge'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Cured/Discharge')
plt.ylabel('Cured/Discharge')
plt.legend(title='Statewise Cured Corona cases by MyGov India')
plt.show()

# %%
Mygov['Death'] = Mygov['Death'].astype(int)

# %%
plt.figure(figsize = (100,100))
PRS.plot.bar('States','Death')
plt.ylabel('Death')
plt.legend(title='Statewise Death Corona cases by MyGov India')
plt.show()

# %%
NDTV = pd.read_csv("NDTVIndiacorona_cases.csv")

# %%
NDTV.head()
# Out:
#    S.no                       States Confirmed cases Active cases  \
# 0     1  Andaman And Nicobar Islands          10,766            0
# 1     2               Andhra Pradesh       23,40,672            0
# 2     3            Arunachal Pradesh          67,042            2
# 3     4                        Assam        7,46,138           19
# 4     5                        Bihar        8,55,252           11
#
#   Cured/Discharge   Death
# 0          10,637     129
# 1       23,25,939  14,733
# 2          66,744     296
# 3        7,38,084   8,035
# 4        8,42,927  12,314

# %%
print(NDTV.dtypes)
# Out:
# S.no                int64
# States             object
# Confirmed cases    object
# Active cases       object
# Cured/Discharge    object
# Death              object
# dtype: object

# %%
import os

cwd = os.getcwd()
files = os.listdir(cwd)
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/home/labsuser': ['store_data.csv', 'practice_svm.ipynb', '13. Machine Learning - 08 Feb 2023.ipynb', 'practice_naive_bayes.ipynb', 'weight-height.csv', 'train.csv', '.gitconfig', 'Time-Series1.ipynb', 'PRSlegislativecorona_cases.csv', 'Multiple Linear Regression.ipynb', 'Project_1.zip', '.config', 'DS with Python Session 11 - Regression Modelling.ipynb', 'Prac_bagging.ipynb', 'Jhonny Depp_images', 'task1.ipynb', 'Heart attack.ipynb', '.ssh', 'practicelinreg.ipynb', 'bank-additional-full.csv', 'Untitled3.ipynb', 'Virat Kohli_images', '.cache', 'User_Data.csv', 'knn practice.ipynb', 'Market basket analysis.ipynb', 'download_googleimages.ipynb', 'Advertising.csv', 'Untitled1.ipynb', 'corona_cases.csv', 'test.csv', '.ipynb_checkpoints', 'website_data.csv', '.voc', 'prac_adaandcat.ipynb', 'XGBOOST.ipynb', 'SVM.ipynb', 'task3.ipynb', 'capstone_realestate.ipynb', 'naive_bayes.ipynb', 'prac_time_series.ipynb', 'train_indessa.csv', 'heart.csv', 'Untitled5.ipynb', 'test.zip', 'Mygov
# ...

# %%
NDTVIndia = pd.read_csv("NDTVcases.csv",header=1)

# %%
NDTVIndia.head()
# Out:
#    S.no                       States  Confirmed cases  Active cases  \
# 0     1  Andaman And Nicobar Islands            10766             0
# 1     2               Andhra Pradesh          2340672             0
# 2     3            Arunachal Pradesh            67042             2
# 3     4                        Assam           746138            19
# 4     5                        Bihar           855252            11
#
#    Cured/Discharge  Death
# 0            10637    129
# 1          2325939  14733
# 2            66744    296
# 3           738084   8035
# 4           842927  12314

# %%
NDTVIndia.drop(['S.no'],axis =1)
# Out:
#                                       States  Confirmed cases  Active cases  \
# 0                Andaman And Nicobar Islands            10766             0
# 1                             Andhra Pradesh          2340672             0
# 2                          Arunachal Pradesh            67042             2
# 3                                      Assam           746138            19
# 4                                      Bihar           855252            11
# 5                                 Chandigarh           100687             1
# 6                               Chhattisgarh          1187676             7
# 7   Dadra And Nagar Haveli And Daman And Diu            11592             0
# 8                                      Delhi          2040758            17
# 9                                        Goa           263279            26
# 10                                   Gujarat          1291344            14
# ...

# %%
print(NDTVIndia.dtypes)
# Out:
# S.no                int64
# States             object
# Confirmed cases     int64
# Active cases        int64
# Cured/Discharge     int64
# Death               int64
# dtype: object

# %%
plt.figure(figsize = (100,100))
NDTVIndia.plot.bar('States','Death')
plt.ylabel('Death')
plt.legend(title='Statewise Death Corona cases by NDTV India')
plt.show()

# %%
plt.figure(figsize = (100,100))
NDTVIndia.plot.bar('States','Confirmed cases')
plt.ylabel('Confirmed cases')
plt.legend(title='Statewise Death Corona cases by NDTV India')
plt.show()

# %%
plt.figure(figsize = (100,100))
NDTVIndia.plot.bar('States','Active cases')
plt.ylabel('Active cases')
plt.legend(title='Statewise Death Corona cases by NDTV India')
plt.show()

# %%
plt.figure(figsize = (100,100))
NDTVIndia.plot.bar('States','Cured/Discharge')
plt.ylabel('Cured/Discharge')
plt.legend(title='Statewise Death Corona cases by NDTV India')
plt.show()
